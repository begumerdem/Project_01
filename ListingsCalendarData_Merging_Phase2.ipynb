# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns 
import statistics
# %matplotlib inline

from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler 
from sklearn.preprocessing import StandardScaler
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error
from sklearn.model_selection import train_test_split

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import pymysql
from sqlalchemy import create_engine

from getpass import getpass  # To get the password without showing the input

# %%
password = getpass()
# Out:
# ········

# %%
connection_string = 'mysql+pymysql://root:'+password+'@localhost/airbnb'
engine = create_engine(connection_string)

# %%
# listings_df = pd.read_csv('abnb_listings_cleaned.csv')
calendar_df = pd.read_csv('abnb_calendar_df_rented.csv')

# %%
listings_df = pd.read_sql_query('SELECT * FROM listings', engine)

# %%
listings_df.head()
# Out:
#       id host_since host_is_superhost neighbourhood  latitude  longitude  \
# 0   4952  2009-2012                 t     Palo Alto  37.43932 -122.15741
# 1  21373  2009-2012                 t     Palo Alto  37.43972 -122.15532
# 2  26622  2009-2012                 f     Daly City  37.69490 -122.47517
# 3  39342  2009-2012                 f      Pacifica  37.62972 -122.48739
# 4  40560  2009-2012                 t     Palo Alto  37.45379 -122.13867
#
#          room_type  accommodates  bedrooms  beds  price  minimum_nights  \
# 0     Private room        Single       1.0   1.0   70.0              31
# 1     Private room        Single       1.0   1.0   70.0              31
# 2     Private room        Couple       1.0   1.0  150.0               3
# 3  Entire home/apt  Small groups       2.0   2.0  138.0              31
# 4     Private room        Couple       1.0   1.0  115.0               2
#
#    maximum_nights  number_of_reviews  review_scores_rating  \
# ...

# %%
calendar_df.head()
# Out:
#            listing_id        date available   price adjusted_price  year  \
# 0  649100413671762836  2022-06-16         f  114.00         114.00  2022
# 1  649100413671762836  2022-06-17         f  114.00         114.00  2022
# 2  649100413671762836  2022-06-18         f  114.00         114.00  2022
# 3  649100413671762836  2022-06-19         f  114.00         114.00  2022
# 4  649100413671762836  2022-06-20         f  114.00         114.00  2022
#
#   month_name  season
# 0       June  spring
# 1       June  spring
# 2       June  spring
# 3       June  spring
# 4       June  spring

# %%
listings_df['id'].max()
# Out:
# 649485279001314237

# %%
airbnb_df = listings_df.merge(calendar_df, how ='inner', left_on = 'id', right_on = 'listing_id' )

# %%
airbnb_df = airbnb_df.drop(columns = ['listing_id', 'price_y'])

# %%
airbnb_df.head()
# Out:
#      id host_since host_is_superhost neighbourhood  latitude  longitude  \
# 0  4952  2009-2012                 t     Palo Alto  37.43932 -122.15741
# 1  4952  2009-2012                 t     Palo Alto  37.43932 -122.15741
# 2  4952  2009-2012                 t     Palo Alto  37.43932 -122.15741
# 3  4952  2009-2012                 t     Palo Alto  37.43932 -122.15741
# 4  4952  2009-2012                 t     Palo Alto  37.43932 -122.15741
#
#       room_type accommodates  bedrooms  beds  price_x  minimum_nights  \
# 0  Private room       Single       1.0   1.0     70.0              31
# 1  Private room       Single       1.0   1.0     70.0              31
# 2  Private room       Single       1.0   1.0     70.0              31
# 3  Private room       Single       1.0   1.0     70.0              31
# 4  Private room       Single       1.0   1.0     70.0              31
#
#    maximum_nights  number_of_reviews  review_scores_rating  \
# ...

# %%
airbnb_df.to_csv("/Users/begumerdem/IH-Labs/WEEK_5_Lab/archive/airbnb_df_final.csv", index = False)

# %%
airbnb_price_per_season_df = airbnb_df.groupby(['id', 'season', 'year'])['price_x'].sum().reset_index()

# %%
airbnb_price_per_season_df.to_csv('price_per_season.csv', index=False)

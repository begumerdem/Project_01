# %% [markdown]
# # Importing the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns 
import statistics
# %matplotlib inline

from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler 
from sklearn.preprocessing import StandardScaler
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error
from sklearn.model_selection import train_test_split

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # Load Data

# %%
abnb_calendar1_df = pd.read_csv('calendar_1.csv.gz')

abnb_calendar2_df = pd.read_csv('calendar.csv.gz')

abnb_calendar_df = pd.concat([abnb_calendar1_df,abnb_calendar2_df],  axis = 0).reset_index(drop=True)
abnb_calendar_df
# Out:
#                  listing_id        date available    price adjusted_price  \
# 0        649100413671762836  2022-06-16         f  $114.00        $114.00
# 1        649100413671762836  2022-06-17         f  $114.00        $114.00
# 2        649100413671762836  2022-06-18         f  $114.00        $114.00
# 3        649100413671762836  2022-06-19         f  $114.00        $114.00
# 4        649100413671762836  2022-06-20         f  $114.00        $114.00
# ...                     ...         ...       ...      ...            ...
# 3316751             1778252  2023-06-11         t  $100.00        $100.00
# 3316752             1778252  2023-06-12         t  $100.00        $100.00
# 3316753             1778252  2023-06-13         t  $100.00        $100.00
# 3316754             1778252  2023-06-14         t  $100.00        $100.00
# 3316755             1778252  2023-06-15         t  $100.00        $100.00
#
#          minimum_nights  maximum_nights
# 0                   1.0           365.0
# 1                   1.0           365.0
# 2                   1.0           365.0
# 3                   1.0           365.0
# 4                   1.0           365.0
# ...                 ...             ...
# 3316751            21.0           730.0
# 3316752            21.0           730.0
# 3316753            21.0           730.0
# 3316754            21.0           730.0
# 3316755            21.0           730.0
#
# [3316756 rows x 7 columns]

# %% [markdown]
# # Discovery

# %%
abnb_calendar_df.isna().sum()
# Out:
# listing_id          0
# date                0
# available           0
# price             183
# adjusted_price    183
# minimum_nights     14
# maximum_nights     14
# dtype: int64

# %%
abnb_calendar_df.duplicated().sum()
abnb_calendar_df = abnb_calendar_df.drop_duplicates()

# %%
abnb_calendar_df.isna().sum()
# Out:
# listing_id          0
# date                0
# available           0
# price             183
# adjusted_price    183
# minimum_nights     14
# maximum_nights     14
# dtype: int64

# %%
abnb_calendar_df.duplicated().sum()
# Out:
# 0

# %%
abnb_calendar_df_rented = abnb_calendar_df[abnb_calendar_df['available'] == 'f' ]
abnb_calendar_df_rented.reset_index(drop = True, inplace=True)
abnb_calendar_df_rented
# Out:
#                  listing_id        date available    price adjusted_price  \
# 0        649100413671762836  2022-06-16         f  $114.00        $114.00
# 1        649100413671762836  2022-06-17         f  $114.00        $114.00
# 2        649100413671762836  2022-06-18         f  $114.00        $114.00
# 3        649100413671762836  2022-06-19         f  $114.00        $114.00
# 4        649100413671762836  2022-06-20         f  $114.00        $114.00
# ...                     ...         ...       ...      ...            ...
# 1589619             1758525  2023-06-11         f  $115.00        $115.00
# 1589620             1758525  2023-06-12         f  $115.00        $115.00
# 1589621             1758525  2023-06-13         f  $115.00        $115.00
# 1589622             1758525  2023-06-14         f  $115.00        $115.00
# 1589623             1758525  2023-06-15         f  $115.00        $115.00
#
#          minimum_nights  maximum_nights
# 0                   1.0           365.0
# 1                   1.0           365.0
# 2                   1.0           365.0
# 3                   1.0           365.0
# 4                   1.0           365.0
# ...                 ...             ...
# 1589619             2.0            30.0
# 1589620             2.0            30.0
# 1589621             2.0            30.0
# 1589622             2.0            30.0
# 1589623             2.0            30.0
#
# [1589624 rows x 7 columns]

# %%
abnb_calendar_df_rented.isna().sum()
# Out:
# listing_id         0
# date               0
# available          0
# price             48
# adjusted_price    48
# minimum_nights    14
# maximum_nights    14
# dtype: int64

# %%
abnb_calendar_df_rented['price'] = abnb_calendar_df_rented['price'].fillna('$115.00')
# Out:
# /var/folders/rj/ty5_khc929v572g5r_tjk0sw0000gn/T/ipykernel_19960/4055710814.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   abnb_calendar_df_rented['price'] = abnb_calendar_df_rented['price'].fillna('$115.00')

# %%
abnb_calendar_df_rented['adjusted_price'] = abnb_calendar_df_rented['adjusted_price'].fillna('$115.00')
# Out:
# /var/folders/rj/ty5_khc929v572g5r_tjk0sw0000gn/T/ipykernel_19960/3375662851.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   abnb_calendar_df_rented['adjusted_price'] = abnb_calendar_df_rented['adjusted_price'].fillna('$115.00')

# %%
abnb_calendar_df_rented = abnb_calendar_df_rented.drop(columns = ['minimum_nights','maximum_nights'])

# %%
abnb_calendar_df_rented
# Out:
#                  listing_id        date available    price adjusted_price
# 0        649100413671762836  2022-06-16         f  $114.00        $114.00
# 1        649100413671762836  2022-06-17         f  $114.00        $114.00
# 2        649100413671762836  2022-06-18         f  $114.00        $114.00
# 3        649100413671762836  2022-06-19         f  $114.00        $114.00
# 4        649100413671762836  2022-06-20         f  $114.00        $114.00
# ...                     ...         ...       ...      ...            ...
# 1589619             1758525  2023-06-11         f  $115.00        $115.00
# 1589620             1758525  2023-06-12         f  $115.00        $115.00
# 1589621             1758525  2023-06-13         f  $115.00        $115.00
# 1589622             1758525  2023-06-14         f  $115.00        $115.00
# 1589623             1758525  2023-06-15         f  $115.00        $115.00
#
# [1589624 rows x 5 columns]

# %%
abnb_calendar_df_rented['price'] = abnb_calendar_df_rented['price'].str.replace('$', '')
abnb_calendar_df_rented['adjusted_price'] = abnb_calendar_df_rented['adjusted_price'].str.replace('$', '')

# %%
abnb_calendar_df_rented
# Out:
#                  listing_id        date available   price adjusted_price
# 0        649100413671762836  2022-06-16         f  114.00         114.00
# 1        649100413671762836  2022-06-17         f  114.00         114.00
# 2        649100413671762836  2022-06-18         f  114.00         114.00
# 3        649100413671762836  2022-06-19         f  114.00         114.00
# 4        649100413671762836  2022-06-20         f  114.00         114.00
# ...                     ...         ...       ...     ...            ...
# 1589619             1758525  2023-06-11         f  115.00         115.00
# 1589620             1758525  2023-06-12         f  115.00         115.00
# 1589621             1758525  2023-06-13         f  115.00         115.00
# 1589622             1758525  2023-06-14         f  115.00         115.00
# 1589623             1758525  2023-06-15         f  115.00         115.00
#
# [1589624 rows x 5 columns]

# %%
test = abnb_calendar_df_rented['price'] == abnb_calendar_df_rented['adjusted_price']

# %%
test.value_counts()
# Out:
# True     1564366
# False      25258
# dtype: int64

# %%
abnb_calendar_df_rented.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1589624 entries, 0 to 1589623
# Data columns (total 5 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   listing_id      1589624 non-null  int64
#  1   date            1589624 non-null  object
#  2   available       1589624 non-null  object
#  3   price           1589624 non-null  object
#  4   adjusted_price  1589624 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 60.6+ MB

# %%
abnb_calendar_df_rented['date']=pd.to_datetime(abnb_calendar_df_rented['date'])

# %%
abnb_calendar_df_rented.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1589624 entries, 0 to 1589623
# Data columns (total 5 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   listing_id      1589624 non-null  int64
#  1   date            1589624 non-null  datetime64[ns]
#  2   available       1589624 non-null  object
#  3   price           1589624 non-null  object
#  4   adjusted_price  1589624 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 60.6+ MB

# %%
abnb_calendar_df_rented['year'] = pd.DatetimeIndex(abnb_calendar_df_rented['date']).year

# %%
abnb_calendar_df_rented['month_name'] = abnb_calendar_df_rented['date'].dt.month_name()

# %%
abnb_calendar_df_rented
# Out:
#                  listing_id       date available   price adjusted_price  year  \
# 0        649100413671762836 2022-06-16         f  114.00         114.00  2022
# 1        649100413671762836 2022-06-17         f  114.00         114.00  2022
# 2        649100413671762836 2022-06-18         f  114.00         114.00  2022
# 3        649100413671762836 2022-06-19         f  114.00         114.00  2022
# 4        649100413671762836 2022-06-20         f  114.00         114.00  2022
# ...                     ...        ...       ...     ...            ...   ...
# 1589619             1758525 2023-06-11         f  115.00         115.00  2023
# 1589620             1758525 2023-06-12         f  115.00         115.00  2023
# 1589621             1758525 2023-06-13         f  115.00         115.00  2023
# 1589622             1758525 2023-06-14         f  115.00         115.00  2023
# 1589623             1758525 2023-06-15         f  115.00         115.00  2023
#
#         month_name
# 0             June
# 1             June
# 2             June
# 3             June
# 4             June
# ...            ...
# 1589619       June
# 1589620       June
# 1589621       June
# 1589622       June
# 1589623       June
#
# [1589624 rows x 7 columns]

# %%
from datetime import date, datetime

Y = 2000 # dummy leap year to allow input X-02-29 (leap day)
seasons = [('winter', (date(Y,  1,  1),  date(Y,  3, 20))),
           ('spring', (date(Y,  3, 21),  date(Y,  6, 20))),
           ('summer', (date(Y,  6, 21),  date(Y,  9, 22))),
           ('autumn', (date(Y,  9, 23),  date(Y, 12, 20))),
           ('winter', (date(Y, 12, 21),  date(Y, 12, 31)))]

def get_season(now):
    if isinstance(now, datetime):
        now = now.date()
    now = now.replace(year=Y)
    return next(season for season, (start, end) in seasons
                if start <= now <= end)

# %%
abnb_calendar_df_rented['season'] = abnb_calendar_df_rented['date'].apply(get_season)

# %%
abnb_calendar_df_rented
# Out:
#                  listing_id       date available   price adjusted_price  year  \
# 0        649100413671762836 2022-06-16         f  114.00         114.00  2022
# 1        649100413671762836 2022-06-17         f  114.00         114.00  2022
# 2        649100413671762836 2022-06-18         f  114.00         114.00  2022
# 3        649100413671762836 2022-06-19         f  114.00         114.00  2022
# 4        649100413671762836 2022-06-20         f  114.00         114.00  2022
# ...                     ...        ...       ...     ...            ...   ...
# 1589619             1758525 2023-06-11         f  115.00         115.00  2023
# 1589620             1758525 2023-06-12         f  115.00         115.00  2023
# 1589621             1758525 2023-06-13         f  115.00         115.00  2023
# 1589622             1758525 2023-06-14         f  115.00         115.00  2023
# 1589623             1758525 2023-06-15         f  115.00         115.00  2023
#
#         month_name  season
# 0             June  spring
# 1             June  spring
# 2             June  spring
# 3             June  spring
# 4             June  spring
# ...            ...     ...
# 1589619       June  spring
# 1589620       June  spring
# 1589621       June  spring
# 1589622       June  spring
# 1589623       June  spring
#
# [1589624 rows x 8 columns]

# %%
abnb_calendar_df_rented.to_csv("/Users/begumerdem/IH-Labs/WEEK_5_Lab/archive/abnb_calendar_df_rented.csv", index = False)

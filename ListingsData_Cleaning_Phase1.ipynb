# %% [markdown]
# # Importing the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns 
import statistics
# %matplotlib inline

from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler 
from sklearn.preprocessing import StandardScaler
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error
from sklearn.model_selection import train_test_split

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # Load Data

# %%
# Showing all the columns and rows. Normally pandas have a max limit.

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %%
# Loading the raw data .csv files into the dataframes

# Decided to get both San Mateo County Airbnb data and Santa Clara County Airbnb Data
# will read these two datasets into my notebook, check their main features, 
# decide what columns might be relevant in the preliminary step of cleaning the data
# then will concat these two dataframes. After concat, I will keep specific locations 
# Specific locations will be: Redwood City, Menlo Park, Palo Alto, Mountain View, and Sunnyvale
# Stanford Palo Alto will be my main point and will check other cities' prices surrounding it

# %%
abnb_sm_df = pd.read_csv('San_Mateo_listings.csv')
abnb_sc_df = pd.read_csv('Santa_Clara_listings.csv')

# %% [markdown]
# # Discovery

# %%
# Looking at the dataframe main features (head, shape, info)

# %%
def df_main_features(df):
    display(df.shape)
    display(df.head())
    display(df.info())
    display(df.isnull().sum())
    display(df.describe())
    return

# %%
df_main_features(abnb_sm_df)
# Out:
# (3358, 74)
#       id                         listing_url       scrape_id last_scraped  \
# 0   4952   https://www.airbnb.com/rooms/4952  20220615153426   2022-06-16
# 1  21373  https://www.airbnb.com/rooms/21373  20220615153426   2022-06-16
# 2  26622  https://www.airbnb.com/rooms/26622  20220615153426   2022-06-15
# 3  39342  https://www.airbnb.com/rooms/39342  20220615153426   2022-06-15
# 4  40560  https://www.airbnb.com/rooms/40560  20220615153426   2022-06-16
#
#                                                name  \
# 0  Butterfly Inn near Stanford with weekly cleaning
# 1  Bonsai Garden near Stanford with weekly cleaning
# 2               Upstairs Bedroom-3 day minimum stay
# 3     Dog friendly. Near the beach. Lovely Cottage.
# 4                         MOST COMFORTABLE BED EVER
#
#                                          description  \
# 0  Small private room with lovely garden setting ...
# 1  Small bedroom and desk Lovely garden setting i...
# 2  Lovely bedroom and bathroom facilities in our ...
# 3  31 NIGHT MINIMUM.  Walk to Pacifica Beach from...
# 4  The "Purple Room," as I call it, is great for ...
#
#                                neighborhood_overview  \
# 0  Located in Professorville, Palo Alto, one of t...
# 1  This room is in an ultra convenient location i...
# 2  Daly City is as multi-cultural as you can get!...
# 3    Quite neighborhood with easy walk to the beach.
# 4  My neighborhood is lovely and a great place to...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/529448/3d73e0...     7054
# 1  https://a0.muscache.com/pictures/527285/0f9d08...     7054
# 2  https://a0.muscache.com/pictures/66176875/1ecd...   113123
# 3  https://a0.muscache.com/pictures/219887/f319d2...   127367
# 4  https://a0.muscache.com/pictures/630306/19db9b...   174725
#
#                                    host_url host_name  host_since  \
# 0    https://www.airbnb.com/users/show/7054   Mei Lin  2009-01-24
# 1    https://www.airbnb.com/users/show/7054   Mei Lin  2009-01-24
# 2  https://www.airbnb.com/users/show/113123       Syd  2010-04-24
# 3  https://www.airbnb.com/users/show/127367  Michelle  2010-05-18
# 4  https://www.airbnb.com/users/show/174725     Megan  2010-07-20
#
#                           host_location  \
# 0  Palo Alto, California, United States
# 1  Palo Alto, California, United States
# 2  Daly City, California, United States
# 3     Sonoma, California, United States
# 4  Palo Alto, California, United States
#
#                                           host_about  host_response_time  \
# 0  I have lived and worked in Asia, Europe, Austr...      within an hour
# 1  I have lived and worked in Asia, Europe, Austr...      within an hour
# 2  I am a retired teacher (20 years First Grade, ...  within a few hours
# 3  I manage 15  properties in San Francisco and P...      within an hour
# 4  Mom, former journalist but now have several bu...      within an hour
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0               100%                  95%                 t
# 1               100%                  95%                 t
# 2               100%                  67%                 f
# 3               100%                  73%                 f
# 4               100%                 100%                 t
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/users/7054/profile_...
# 1  https://a0.muscache.com/im/users/7054/profile_...
# 2  https://a0.muscache.com/im/users/113123/profil...
# 3  https://a0.muscache.com/im/pictures/user/d08c9...
# 4  https://a0.muscache.com/im/users/174725/profil...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/7054/profile_...          Palo Alto
# 1  https://a0.muscache.com/im/users/7054/profile_...          Palo Alto
# 2  https://a0.muscache.com/im/users/113123/profil...          Daly City
# 3  https://a0.muscache.com/im/pictures/user/d08c9...           Pacifica
# 4  https://a0.muscache.com/im/users/174725/profil...          Palo Alto
#
#    host_listings_count  host_total_listings_count  \
# 0                    5                          5
# 1                    5                          5
# 2                    1                          1
# 3                   28                         28
# 4                    0                          0
#
#                  host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'work_email']                    t
# 1  ['email', 'phone', 'work_email']                    t
# 2                ['email', 'phone']                    t
# 3                ['email', 'phone']                    t
# 4                ['email', 'phone']                    t
#
#   host_identity_verified                         neighbourhood  \
# 0                      t  Palo Alto, California, United States
# 1                      t  Palo Alto, California, United States
# 2                      f  Daly City, California, United States
# 3                      t   Pacifica, California, United States
# 4                      t  Palo Alto, California, United States
#
#   neighbourhood_cleansed  neighbourhood_group_cleansed  latitude  longitude  \
# 0   Unincorporated Areas                           NaN  37.43932 -122.15741
# 1   Unincorporated Areas                           NaN  37.43972 -122.15532
# 2              Daly City                           NaN  37.69490 -122.47517
# 3               Pacifica                           NaN  37.62972 -122.48739
# 4   Unincorporated Areas                           NaN  37.45379 -122.13867
#
#           property_type        room_type  accommodates  bathrooms  \
# 0          Private room     Private room             1        NaN
# 1          Private room     Private room             1        NaN
# 2  Private room in home     Private room             2        NaN
# 3           Entire home  Entire home/apt             3        NaN
# 4  Private room in home     Private room             2        NaN
#
#      bathrooms_text  bedrooms  beds  \
# 0    2 shared baths       1.0   1.0
# 1    2 shared baths       1.0   1.0
# 2  1.5 shared baths       1.0   1.0
# 3            1 bath       2.0   2.0
# 4     1 shared bath       1.0   1.0
#
#                                            amenities    price  minimum_nights  \
# 0  ["Freezer", "Lock on bedroom door", "Carbon mo...   $70.00              31
# 1  ["Freezer", "Lock on bedroom door", "Carbon mo...   $70.00              31
# 2  ["Lock on bedroom door", "Carbon monoxide alar...  $150.00               3
# 3  ["Keypad", "Carbon monoxide alarm", "TV with s...  $138.00              31
# 4  ["Backyard", "Carbon monoxide alarm", "TV with...  $115.00               2
#
#    maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 0             365                      31                      31
# 1             365                      31                      31
# 2               7                       3                       3
# 3             365                      31                      31
# 4             100                       2                       2
#
#    minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                     365                     365                    31.0
# 1                     365                     365                    31.0
# 2                       7                       7                     3.0
# 3                     365                     365                    31.0
# 4                     100                     100                     2.0
#
#    maximum_nights_avg_ntm  calendar_updated has_availability  availability_30  \
# 0                   365.0               NaN                t                0
# 1                   365.0               NaN                t                0
# 2                     7.0               NaN                t               21
# 3                   365.0               NaN                t                0
# 4                   100.0               NaN                t                0
#
#    availability_60  availability_90  availability_365 calendar_last_scraped  \
# 0                0                0                58            2022-06-16
# 1                0                0                 0            2022-06-16
# 2               47               77               352            2022-06-15
# 3                0                0               260            2022-06-15
# 4                0                0               255            2022-06-16
#
#    number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# 0                 76                      1                       0
# 1                264                      1                       0
# 2                255                      1                       1
# 3                  3                      1                       0
# 4                139                      5                       1
#
#   first_review last_review  review_scores_rating  review_scores_accuracy  \
# 0   2009-08-02  2022-04-02                  4.79                    4.81
# 1   2010-05-28  2022-05-15                  4.87                    4.82
# 2   2010-07-02  2022-05-29                  4.96                    4.96
# 3   2010-08-22  2022-02-05                  4.67                    5.00
# 4   2010-09-18  2022-06-12                  4.91                    4.94
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       4.88                   4.86
# 1                       4.79                   4.85
# 2                       4.97                   4.96
# 3                       5.00                   4.50
# 4                       4.95                   4.90
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.83                    4.89                 4.78
# 1                         4.90                    4.96                 4.74
# 2                         4.95                    4.73                 4.92
# 3                         5.00                    5.00                 5.00
# 4                         4.95                    4.94                 4.83
#
#   license instant_bookable  calculated_host_listings_count  \
# 0     NaN                f                               5
# 1     NaN                f                               5
# 2     NaN                f                               1
# 3     NaN                f                               2
# 4     NaN                f                               2
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            2
# 4                                            0
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             5
# 1                                             5
# 2                                             1
# 3                                             0
# 4                                             2
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.48
# 1                                            0               1.80
# 2                                            0               1.75
# 3                                            0               0.02
# 4                                            0               0.97
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3358 entries, 0 to 3357
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            3358 non-null   int64
#  1   listing_url                                   3358 non-null   object
#  2   scrape_id                                     3358 non-null   int64
#  3   last_scraped                                  3358 non-null   object
#  4   name                                          3358 non-null   object
#  5   description                                   3317 non-null   object
#  6   neighborhood_overview                         2340 non-null   object
#  7   picture_url                                   3358 non-null   object
#  8   host_id                                       3358 non-null   int64
#  9   host_url                                      3358 non-null   object
#  10  host_name                                     3358 non-null   object
#  11  host_since                                    3358 non-null   object
#  12  host_location                                 3355 non-null   object
#  13  host_about                                    2213 non-null   object
#  14  host_response_time                            3025 non-null   object
#  15  host_response_rate                            3025 non-null   object
#  16  host_acceptance_rate                          3142 non-null   object
#  17  host_is_superhost                             3358 non-null   object
#  18  host_thumbnail_url                            3358 non-null   object
#  19  host_picture_url                              3358 non-null   object
#  20  host_neighbourhood                            2820 non-null   object
#  21  host_listings_count                           3358 non-null   int64
#  22  host_total_listings_count                     3358 non-null   int64
#  23  host_verifications                            3358 non-null   object
#  24  host_has_profile_pic                          3358 non-null   object
#  25  host_identity_verified                        3358 non-null   object
#  26  neighbourhood                                 2340 non-null   object
#  27  neighbourhood_cleansed                        3358 non-null   object
#  28  neighbourhood_group_cleansed                  0 non-null      float64
#  29  latitude                                      3358 non-null   float64
#  30  longitude                                     3358 non-null   float64
#  31  property_type                                 3358 non-null   object
#  32  room_type                                     3358 non-null   object
#  33  accommodates                                  3358 non-null   int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                3353 non-null   object
#  36  bedrooms                                      3135 non-null   float64
#  37  beds                                          3304 non-null   float64
#  38  amenities                                     3358 non-null   object
#  39  price                                         3358 non-null   object
#  40  minimum_nights                                3358 non-null   int64
#  41  maximum_nights                                3358 non-null   int64
#  42  minimum_minimum_nights                        3358 non-null   int64
#  43  maximum_minimum_nights                        3358 non-null   int64
#  44  minimum_maximum_nights                        3358 non-null   int64
#  45  maximum_maximum_nights                        3358 non-null   int64
#  46  minimum_nights_avg_ntm                        3358 non-null   float64
#  47  maximum_nights_avg_ntm                        3358 non-null   float64
#  48  calendar_updated                              0 non-null      float64
#  49  has_availability                              3358 non-null   object
#  50  availability_30                               3358 non-null   int64
#  51  availability_60                               3358 non-null   int64
#  52  availability_90                               3358 non-null   int64
#  53  availability_365                              3358 non-null   int64
#  54  calendar_last_scraped                         3358 non-null   object
#  55  number_of_reviews                             3358 non-null   int64
#  56  number_of_reviews_ltm                         3358 non-null   int64
#  57  number_of_reviews_l30d                        3358 non-null   int64
#  58  first_review                                  2855 non-null   object
#  59  last_review                                   2855 non-null   object
#  60  review_scores_rating                          2855 non-null   float64
#  61  review_scores_accuracy                        2849 non-null   float64
#  62  review_scores_cleanliness                     2849 non-null   float64
#  63  review_scores_checkin                         2849 non-null   float64
#  64  review_scores_communication                   2849 non-null   float64
#  65  review_scores_location                        2849 non-null   float64
#  66  review_scores_value                           2849 non-null   float64
#  67  license                                       260 non-null    object
#  68  instant_bookable                              3358 non-null   object
#  69  calculated_host_listings_count                3358 non-null   int64
#  70  calculated_host_listings_count_entire_homes   3358 non-null   int64
#  71  calculated_host_listings_count_private_rooms  3358 non-null   int64
#  72  calculated_host_listings_count_shared_rooms   3358 non-null   int64
#  73  reviews_per_month                             2855 non-null   float64
# dtypes: float64(17), int64(23), object(34)
# memory usage: 1.9+ MB
# None
# id                                                 0
# listing_url                                        0
# scrape_id                                          0
# last_scraped                                       0
# name                                               0
# description                                       41
# neighborhood_overview                           1018
# picture_url                                        0
# host_id                                            0
# host_url                                           0
# host_name                                          0
# host_since                                         0
# host_location                                      3
# host_about                                      1145
# host_response_time                               333
# host_response_rate                               333
# host_acceptance_rate                             216
# host_is_superhost                                  0
# host_thumbnail_url                                 0
# host_picture_url                                   0
# host_neighbourhood                               538
# host_listings_count                                0
# host_total_listings_count                          0
# host_verifications                                 0
# host_has_profile_pic                               0
# host_identity_verified                             0
# neighbourhood                                   1018
# neighbourhood_cleansed                             0
# neighbourhood_group_cleansed                    3358
# latitude                                           0
# longitude                                          0
# property_type                                      0
# room_type                                          0
# accommodates                                       0
# bathrooms                                       3358
# bathrooms_text                                     5
# bedrooms                                         223
# beds                                              54
# amenities                                          0
# price                                              0
# minimum_nights                                     0
# maximum_nights                                     0
# minimum_minimum_nights                             0
# maximum_minimum_nights                             0
# minimum_maximum_nights                             0
# maximum_maximum_nights                             0
# minimum_nights_avg_ntm                             0
# maximum_nights_avg_ntm                             0
# calendar_updated                                3358
# has_availability                                   0
# availability_30                                    0
# availability_60                                    0
# availability_90                                    0
# availability_365                                   0
# calendar_last_scraped                              0
# number_of_reviews                                  0
# number_of_reviews_ltm                              0
# number_of_reviews_l30d                             0
# first_review                                     503
# last_review                                      503
# review_scores_rating                             503
# review_scores_accuracy                           509
# review_scores_cleanliness                        509
# review_scores_checkin                            509
# review_scores_communication                      509
# review_scores_location                           509
# review_scores_value                              509
# license                                         3098
# instant_bookable                                   0
# calculated_host_listings_count                     0
# calculated_host_listings_count_entire_homes        0
# calculated_host_listings_count_private_rooms       0
# calculated_host_listings_count_shared_rooms        0
# reviews_per_month                                503
# dtype: int64
#                  id     scrape_id       host_id  host_listings_count  \
# count  3.358000e+03  3.358000e+03  3.358000e+03          3358.000000
# mean   7.216392e+16  2.022062e+13  1.134449e+08           225.823407
# std    1.954779e+17  1.468969e+00  1.253650e+08           754.245304
# min    4.952000e+03  2.022062e+13  7.054000e+03             0.000000
# 25%    2.098340e+07  2.022062e+13  1.590209e+07             1.000000
# 50%    3.755862e+07  2.022062e+13  5.771725e+07             2.000000
# 75%    5.113984e+07  2.022062e+13  1.747920e+08             9.000000
# max    6.491004e+17  2.022062e+13  4.633031e+08          3322.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed     latitude  \
# count                3358.000000                           0.0  3358.000000
# mean                  225.823407                           NaN    37.561683
# std                   754.245304                           NaN     0.103341
# min                     0.000000                           NaN    37.137190
# 25%                     1.000000                           NaN    37.468257
# 50%                     2.000000                           NaN    37.549075
# 75%                     9.000000                           NaN    37.658358
# max                  3322.000000                           NaN    37.728360
#
#          longitude  accommodates  bathrooms     bedrooms         beds  \
# count  3358.000000   3358.000000        0.0  3135.000000  3304.000000
# mean   -122.330873      3.848124        NaN     1.790112     2.252724
# std       0.122456      2.965322        NaN     1.175409     1.923607
# min    -122.519040      0.000000        NaN     1.000000     1.000000
# 25%    -122.445817      2.000000        NaN     1.000000     1.000000
# 50%    -122.336850      3.000000        NaN     1.000000     2.000000
# 75%    -122.219080      5.000000        NaN     2.000000     3.000000
# max    -122.111290     16.000000        NaN     8.000000    27.000000
#
#        minimum_nights  maximum_nights  minimum_minimum_nights  \
# count     3358.000000     3358.000000             3358.000000
# mean        11.314175      600.114056               18.972901
# std         22.333177      528.322304               82.565096
# min          1.000000        1.000000                1.000000
# 25%          1.000000       45.000000                1.000000
# 50%          2.000000      365.000000                2.000000
# 75%         20.000000     1125.000000               14.000000
# max        365.000000    10000.000000              730.000000
#
#        maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# count             3358.000000            3.358000e+03            3.358000e+03
# mean                44.058666            2.558844e+06            2.558877e+06
# std                151.278875            7.408413e+07            7.408413e+07
# min                  1.000000            1.000000e+00            1.000000e+00
# 25%                  2.000000            3.600000e+02            3.650000e+02
# 50%                  3.000000            1.125000e+03            1.125000e+03
# 75%                 28.000000            1.125000e+03            1.125000e+03
# max                730.000000            2.147484e+09            2.147484e+09
#
#        minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# count             3358.000000            3.358000e+03               0.0
# mean                42.528529            2.558868e+06               NaN
# std                148.070209            7.408413e+07               NaN
# min                  1.000000            1.000000e+00               NaN
# 25%                  1.800000            3.650000e+02               NaN
# 50%                  3.000000            1.125000e+03               NaN
# 75%                 21.000000            1.125000e+03               NaN
# max                730.000000            2.147484e+09               NaN
#
#        availability_30  availability_60  availability_90  availability_365  \
# count      3358.000000      3358.000000      3358.000000       3358.000000
# mean          6.582490        17.504467        35.463669        177.131030
# std           8.640447        18.659128        27.843123        122.760363
# min           0.000000         0.000000         0.000000          0.000000
# 25%           0.000000         0.000000        10.000000         65.000000
# 50%           2.000000        12.000000        32.000000        167.000000
# 75%          11.000000        30.000000        58.000000        301.000000
# max          30.000000        60.000000        90.000000        365.000000
#
#        number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# count        3358.000000            3358.000000             3358.000000
# mean           54.636391              14.034544                1.348719
# std            86.047498              20.899536                2.159326
# min             0.000000               0.000000                0.000000
# 25%             2.000000               0.000000                0.000000
# 50%            19.000000               4.000000                0.000000
# 75%            70.000000              20.000000                2.000000
# max           885.000000             187.000000               22.000000
#
#        review_scores_rating  review_scores_accuracy  \
# count           2855.000000             2849.000000
# mean               4.766483                4.830702
# std                0.426797                0.318881
# min                0.000000                1.000000
# 25%                4.710000                4.790000
# 50%                4.880000                4.920000
# 75%                4.980000                5.000000
# max                5.000000                5.000000
#
#        review_scores_cleanliness  review_scores_checkin  \
# count                2849.000000            2849.000000
# mean                    4.785869               4.890530
# std                     0.369339               0.290838
# min                     1.000000               1.000000
# 25%                     4.730000               4.890000
# 50%                     4.900000               4.970000
# 75%                     5.000000               5.000000
# max                     5.000000               5.000000
#
#        review_scores_communication  review_scores_location  \
# count                  2849.000000             2849.000000
# mean                      4.865721                4.801232
# std                       0.334824                0.308900
# min                       1.000000                1.000000
# 25%                       4.860000                4.740000
# 50%                       4.960000                4.880000
# 75%                       5.000000                5.000000
# max                       5.000000                5.000000
#
#        review_scores_value  calculated_host_listings_count  \
# count          2849.000000                     3358.000000
# mean              4.716164                       13.334127
# std               0.359869                       33.385862
# min               1.000000                        1.000000
# 25%               4.640000                        1.000000
# 50%               4.800000                        2.000000
# 75%               4.910000                        6.000000
# max               5.000000                      152.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                  3358.000000
# mean                                     11.608100
# std                                      33.626443
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       1.000000
# 75%                                       3.000000
# max                                     152.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                   3358.000000
# mean                                       1.482132
# std                                        3.492638
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        2.000000
# max                                       27.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                  3358.000000        2855.000000
# mean                                      0.243597           1.857349
# std                                       2.108802           1.892206
# min                                       0.000000           0.010000
# 25%                                       0.000000           0.420000
# 50%                                       0.000000           1.230000
# 75%                                       0.000000           2.690000
# max                                      24.000000          17.740000

# %%
df_main_features(abnb_sc_df)
# Out:
# (5729, 74)
#                    id                                      listing_url  \
# 0  649100413671762836  https://www.airbnb.com/rooms/649100413671762836
# 1            34284906            https://www.airbnb.com/rooms/34284906
# 2            48658485            https://www.airbnb.com/rooms/48658485
# 3            22251361            https://www.airbnb.com/rooms/22251361
# 4            20761499            https://www.airbnb.com/rooms/20761499
#
#         scrape_id last_scraped  \
# 0  20220615153449   2022-06-16
# 1  20220615153449   2022-06-15
# 2  20220615153449   2022-06-15
# 3  20220615153449   2022-06-15
# 4  20220615153449   2022-06-15
#
#                                                 name  \
# 0              Cozy&Cheerful Luxuery bay trail house
# 1                      Skyline and Heaven Guesthouse
# 2    Modern 1 Bed/1 Bath with prvt entry, prvt patio
# 3                 Remote Mountain Suite with Hot Tub
# 4  Lovely Private Room in Menlo Park near Stanford U
#
#                                          description  \
# 0   Kick back and relax in this calm, stylish space.
# 1                                                NaN
# 2  Introducing beautiful newly-constructed privat...
# 3  One-bedroom attached in-law suite with private...
# 4  Lovely  private room in a beautiful 3 bedroom ...
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Rural Mountain residential setting in the redw...
# 4  One of the best neighborhoods in the Bay Area....
#
#                                          picture_url   host_id  \
# 0  https://a0.muscache.com/pictures/miso/Hosting-...  81523960
# 1  https://a0.muscache.com/pictures/23470d5b-5ba4...   7043660
# 2  https://a0.muscache.com/pictures/b8998210-4075...  26479513
# 3  https://a0.muscache.com/pictures/20c61acb-d609...  50031570
# 4  https://a0.muscache.com/pictures/miso/Hosting-...  77312665
#
#                                      host_url host_name  host_since  \
# 0  https://www.airbnb.com/users/show/81523960    Monica  2016-07-03
# 1   https://www.airbnb.com/users/show/7043660   Rebecca  2013-06-21
# 2  https://www.airbnb.com/users/show/26479513    Ashish  2015-01-21
# 3  https://www.airbnb.com/users/show/50031570     Emily  2015-11-28
# 4  https://www.airbnb.com/users/show/77312665      Karn  2016-06-12
#
#                                 host_location  \
# 0        Palo Alto, California, United States
# 1         Woodside, California, United States
# 2          Fremont, California, United States
# 3        Los Gatos, California, United States
# 4  West Menlo Park, California, United States
#
#                                           host_about host_response_time  \
# 0                                                NaN                NaN
# 1  we are home designers and developers from the ...                NaN
# 2                                                NaN     within an hour
# 3  Attorney, outdoor enthusiast, Park City Utah n...     within an hour
# 4   I was born in Delhi and came to the bay area ...     within an hour
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0                NaN                  NaN                 f
# 1                NaN                  NaN                 f
# 2               100%                 100%                 t
# 3               100%                  97%                 t
# 4               100%                  86%                 f
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/user/c5f67...
# 1  https://a0.muscache.com/im/pictures/user/cdbb4...
# 2  https://a0.muscache.com/im/pictures/user/6994a...
# 3  https://a0.muscache.com/im/pictures/user/415c5...
# 4  https://a0.muscache.com/im/pictures/user/badff...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/user/c5f67...                NaN
# 1  https://a0.muscache.com/im/pictures/user/cdbb4...                NaN
# 2  https://a0.muscache.com/im/pictures/user/6994a...       Warm Springs
# 3  https://a0.muscache.com/im/pictures/user/415c5...                NaN
# 4  https://a0.muscache.com/im/pictures/user/badff...         Menlo Park
#
#    host_listings_count  host_total_listings_count  \
# 0                    1                          1
# 1                    1                          1
# 2                    5                          5
# 3                    1                          1
# 4                    1                          1
#
#                  host_verifications host_has_profile_pic  \
# 0                ['email', 'phone']                    t
# 1                ['email', 'phone']                    t
# 2                ['email', 'phone']                    t
# 3  ['email', 'phone', 'work_email']                    t
# 4                ['email', 'phone']                    t
#
#   host_identity_verified                          neighbourhood  \
# 0                      t                                    NaN
# 1                      t                                    NaN
# 2                      t                                    NaN
# 3                      t   Los Gatos, California, United States
# 4                      t  Menlo Park, California, United States
#
#   neighbourhood_cleansed  neighbourhood_group_cleansed  latitude  longitude  \
# 0              Palo Alto                           NaN  37.46911 -122.13203
# 1   Unincorporated Areas                           NaN  37.32758 -122.20766
# 2               Milpitas                           NaN  37.47384 -121.91877
# 3   Unincorporated Areas                           NaN  37.12520 -121.98971
# 4   Unincorporated Areas                           NaN  37.42539 -122.20023
#
#                  property_type        room_type  accommodates  bathrooms  \
# 0          Shared room in home      Shared room             2        NaN
# 1            Entire guesthouse  Entire home/apt             2        NaN
# 2         Private room in home     Private room             2        NaN
# 3           Entire guest suite  Entire home/apt             3        NaN
# 4  Private room in rental unit     Private room             1        NaN
#
#    bathrooms_text  bedrooms  beds  \
# 0   1 shared bath       1.0   2.0
# 1          1 bath       1.0   NaN
# 2  1 private bath       1.0   1.0
# 3          1 bath       1.0   1.0
# 4   1 shared bath       1.0   1.0
#
#                                            amenities    price  minimum_nights  \
# 0  ["Outdoor dining area", "Long term stays allow...   $85.00               1
# 1  ["Essentials", "Free parking on premises", "Pr...  $299.00               3
# 2  ["Essentials", "Air conditioning", "Long term ...   $72.00               1
# 3  ["Essentials", "Clothing storage: dresser and ...  $130.00               2
# 4  ["Essentials", "Air conditioning", "Long term ...   $99.00               1
#
#    maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 0             365                       1                       1
# 1            1125                       3                       3
# 2            1125                       1                       1
# 3              28                       2                       3
# 4            1125                       1                       1
#
#    minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                     365                     365                     1.0
# 1                    1125                    1125                     3.0
# 2                    1125                    1125                     1.0
# 3                    1125                    1125                     2.3
# 4                    1125                    1125                     1.0
#
#    maximum_nights_avg_ntm  calendar_updated has_availability  availability_30  \
# 0                   365.0               NaN                t                0
# 1                  1125.0               NaN                t               23
# 2                  1125.0               NaN                t                4
# 3                  1125.0               NaN                t                0
# 4                  1125.0               NaN                t                0
#
#    availability_60  availability_90  availability_365 calendar_last_scraped  \
# 0                0               10               284            2022-06-16
# 1               53               83                83            2022-06-15
# 2               30               60                60            2022-06-15
# 3                0               12                75            2022-06-15
# 4                1                2                92            2022-06-15
#
#    number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# 0                  0                      0                       0
# 1                  0                      0                       0
# 2                 48                     36                       3
# 3                193                     52                       6
# 4                  8                      5                       0
#
#   first_review last_review  review_scores_rating  review_scores_accuracy  \
# 0          NaN         NaN                   NaN                     NaN
# 1          NaN         NaN                   NaN                     NaN
# 2   2021-03-18  2022-06-06                  4.83                    4.92
# 3   2018-02-26  2022-06-13                  4.94                    4.93
# 4   2017-09-14  2022-03-31                  4.88                    4.88
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                        NaN                    NaN
# 1                        NaN                    NaN
# 2                       4.75                   4.92
# 3                       4.88                   4.99
# 4                       4.38                   5.00
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                          NaN                     NaN                  NaN
# 1                          NaN                     NaN                  NaN
# 2                         5.00                    4.92                 4.79
# 3                         4.94                    4.89                 4.92
# 4                         5.00                    4.75                 5.00
#
#   license instant_bookable  calculated_host_listings_count  \
# 0     NaN                f                               3
# 1     NaN                f                               1
# 2     NaN                t                               5
# 3     NaN                f                               1
# 4     NaN                f                               2
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            2
# 1                                            1
# 2                                            1
# 3                                            1
# 4                                            0
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             0
# 2                                             4
# 3                                             0
# 4                                             2
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            1                NaN
# 1                                            0                NaN
# 2                                            0               3.16
# 3                                            0               3.69
# 4                                            0               0.14
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5729 entries, 0 to 5728
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            5729 non-null   int64
#  1   listing_url                                   5729 non-null   object
#  2   scrape_id                                     5729 non-null   int64
#  3   last_scraped                                  5729 non-null   object
#  4   name                                          5728 non-null   object
#  5   description                                   5609 non-null   object
#  6   neighborhood_overview                         3479 non-null   object
#  7   picture_url                                   5729 non-null   object
#  8   host_id                                       5729 non-null   int64
#  9   host_url                                      5729 non-null   object
#  10  host_name                                     5729 non-null   object
#  11  host_since                                    5729 non-null   object
#  12  host_location                                 5717 non-null   object
#  13  host_about                                    3820 non-null   object
#  14  host_response_time                            5051 non-null   object
#  15  host_response_rate                            5051 non-null   object
#  16  host_acceptance_rate                          5268 non-null   object
#  17  host_is_superhost                             5729 non-null   object
#  18  host_thumbnail_url                            5729 non-null   object
#  19  host_picture_url                              5729 non-null   object
#  20  host_neighbourhood                            4827 non-null   object
#  21  host_listings_count                           5729 non-null   int64
#  22  host_total_listings_count                     5729 non-null   int64
#  23  host_verifications                            5729 non-null   object
#  24  host_has_profile_pic                          5729 non-null   object
#  25  host_identity_verified                        5729 non-null   object
#  26  neighbourhood                                 3479 non-null   object
#  27  neighbourhood_cleansed                        5729 non-null   object
#  28  neighbourhood_group_cleansed                  0 non-null      float64
#  29  latitude                                      5729 non-null   float64
#  30  longitude                                     5729 non-null   float64
#  31  property_type                                 5729 non-null   object
#  32  room_type                                     5729 non-null   object
#  33  accommodates                                  5729 non-null   int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                5723 non-null   object
#  36  bedrooms                                      5347 non-null   float64
#  37  beds                                          5620 non-null   float64
#  38  amenities                                     5729 non-null   object
#  39  price                                         5729 non-null   object
#  40  minimum_nights                                5729 non-null   int64
#  41  maximum_nights                                5729 non-null   int64
#  42  minimum_minimum_nights                        5729 non-null   int64
#  43  maximum_minimum_nights                        5729 non-null   int64
#  44  minimum_maximum_nights                        5729 non-null   int64
#  45  maximum_maximum_nights                        5729 non-null   int64
#  46  minimum_nights_avg_ntm                        5729 non-null   float64
#  47  maximum_nights_avg_ntm                        5729 non-null   float64
#  48  calendar_updated                              0 non-null      float64
#  49  has_availability                              5729 non-null   object
#  50  availability_30                               5729 non-null   int64
#  51  availability_60                               5729 non-null   int64
#  52  availability_90                               5729 non-null   int64
#  53  availability_365                              5729 non-null   int64
#  54  calendar_last_scraped                         5729 non-null   object
#  55  number_of_reviews                             5729 non-null   int64
#  56  number_of_reviews_ltm                         5729 non-null   int64
#  57  number_of_reviews_l30d                        5729 non-null   int64
#  58  first_review                                  4606 non-null   object
#  59  last_review                                   4606 non-null   object
#  60  review_scores_rating                          4606 non-null   float64
#  61  review_scores_accuracy                        4585 non-null   float64
#  62  review_scores_cleanliness                     4585 non-null   float64
#  63  review_scores_checkin                         4585 non-null   float64
#  64  review_scores_communication                   4585 non-null   float64
#  65  review_scores_location                        4585 non-null   float64
#  66  review_scores_value                           4585 non-null   float64
#  67  license                                       55 non-null     object
#  68  instant_bookable                              5729 non-null   object
#  69  calculated_host_listings_count                5729 non-null   int64
#  70  calculated_host_listings_count_entire_homes   5729 non-null   int64
#  71  calculated_host_listings_count_private_rooms  5729 non-null   int64
#  72  calculated_host_listings_count_shared_rooms   5729 non-null   int64
#  73  reviews_per_month                             4606 non-null   float64
# dtypes: float64(17), int64(23), object(34)
# memory usage: 3.2+ MB
# None
# id                                                 0
# listing_url                                        0
# scrape_id                                          0
# last_scraped                                       0
# name                                               1
# description                                      120
# neighborhood_overview                           2250
# picture_url                                        0
# host_id                                            0
# host_url                                           0
# host_name                                          0
# host_since                                         0
# host_location                                     12
# host_about                                      1909
# host_response_time                               678
# host_response_rate                               678
# host_acceptance_rate                             461
# host_is_superhost                                  0
# host_thumbnail_url                                 0
# host_picture_url                                   0
# host_neighbourhood                               902
# host_listings_count                                0
# host_total_listings_count                          0
# host_verifications                                 0
# host_has_profile_pic                               0
# host_identity_verified                             0
# neighbourhood                                   2250
# neighbourhood_cleansed                             0
# neighbourhood_group_cleansed                    5729
# latitude                                           0
# longitude                                          0
# property_type                                      0
# room_type                                          0
# accommodates                                       0
# bathrooms                                       5729
# bathrooms_text                                     6
# bedrooms                                         382
# beds                                             109
# amenities                                          0
# price                                              0
# minimum_nights                                     0
# maximum_nights                                     0
# minimum_minimum_nights                             0
# maximum_minimum_nights                             0
# minimum_maximum_nights                             0
# maximum_maximum_nights                             0
# minimum_nights_avg_ntm                             0
# maximum_nights_avg_ntm                             0
# calendar_updated                                5729
# has_availability                                   0
# availability_30                                    0
# availability_60                                    0
# availability_90                                    0
# availability_365                                   0
# calendar_last_scraped                              0
# number_of_reviews                                  0
# number_of_reviews_ltm                              0
# number_of_reviews_l30d                             0
# first_review                                    1123
# last_review                                     1123
# review_scores_rating                            1123
# review_scores_accuracy                          1144
# review_scores_cleanliness                       1144
# review_scores_checkin                           1144
# review_scores_communication                     1144
# review_scores_location                          1144
# review_scores_value                             1144
# license                                         5674
# instant_bookable                                   0
# calculated_host_listings_count                     0
# calculated_host_listings_count_entire_homes        0
# calculated_host_listings_count_private_rooms       0
# calculated_host_listings_count_shared_rooms        0
# reviews_per_month                               1123
# dtype: int64
#                  id     scrape_id       host_id  host_listings_count  \
# count  5.729000e+03  5.729000e+03  5.729000e+03          5729.000000
# mean   8.188610e+16  2.022062e+13  1.233078e+08           301.879909
# std    2.064451e+17  2.101746e+00  1.257586e+08           848.718328
# min    4.952000e+03  2.022062e+13  7.054000e+03             0.000000
# 25%    2.188225e+07  2.022062e+13  2.470909e+07             1.000000
# 50%    3.977334e+07  2.022062e+13  7.174905e+07             3.000000
# 75%    5.151011e+07  2.022062e+13  1.912639e+08            16.000000
# max    6.494853e+17  2.022062e+13  4.633031e+08          3322.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed     latitude  \
# count                5729.000000                           0.0  5729.000000
# mean                  301.879909                           NaN    37.351373
# std                   848.718328                           NaN     0.073936
# min                     0.000000                           NaN    36.965600
# 25%                     1.000000                           NaN    37.319546
# 50%                     3.000000                           NaN    37.355380
# 75%                    16.000000                           NaN    37.399790
# max                  3322.000000                           NaN    37.480080
#
#          longitude  accommodates  bathrooms     bedrooms         beds  \
# count  5729.000000   5729.000000        0.0  5347.000000  5620.000000
# mean   -121.974697      3.290103        NaN     1.619600     1.931317
# std       0.118236      2.418787        NaN     1.037482     1.502533
# min    -122.214140      0.000000        NaN     1.000000     1.000000
# 25%    -122.070110      2.000000        NaN     1.000000     1.000000
# 50%    -121.962340      2.000000        NaN     1.000000     1.000000
# 75%    -121.890230      4.000000        NaN     2.000000     2.000000
# max    -121.380120     16.000000        NaN     9.000000    20.000000
#
#        minimum_nights  maximum_nights  minimum_minimum_nights  \
# count     5729.000000     5729.000000             5729.000000
# mean        13.176121      641.914645               20.813056
# std         26.861549      494.059806               82.061918
# min          1.000000        1.000000                1.000000
# 25%          1.000000       90.000000                1.000000
# 50%          3.000000      765.000000                3.000000
# 75%         30.000000     1125.000000               28.000000
# max        600.000000     1125.000000              730.000000
#
#        maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# count             5729.000000            5.729000e+03            5.729000e+03
# mean                57.829290            4.873817e+06            6.748048e+06
# std                176.343664            1.021896e+08            1.201935e+08
# min                  1.000000            1.000000e+00            1.000000e+00
# 25%                  2.000000            3.650000e+02            3.650000e+02
# 50%                  3.000000            1.125000e+03            1.125000e+03
# 75%                 30.000000            1.125000e+03            1.125000e+03
# max                730.000000            2.147484e+09            2.147484e+09
#
#        minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# count             5729.000000            5.729000e+03               0.0
# mean                56.081533            6.071292e+06               NaN
# std                172.044535            1.103574e+08               NaN
# min                  1.000000            1.000000e+00               NaN
# 25%                  2.000000            3.650000e+02               NaN
# 50%                  3.000000            1.125000e+03               NaN
# 75%                 29.500000            1.125000e+03               NaN
# max                730.000000            2.147484e+09               NaN
#
#        availability_30  availability_60  availability_90  availability_365  \
# count      5729.000000      5729.000000      5729.000000       5729.000000
# mean          5.618782        15.149590        32.486821        178.089544
# std           8.726939        18.951832        28.325883        127.925597
# min           0.000000         0.000000         0.000000          0.000000
# 25%           0.000000         0.000000         4.000000         54.000000
# 50%           0.000000         6.000000        28.000000        167.000000
# 75%           9.000000        27.000000        54.000000        303.000000
# max          30.000000        60.000000        90.000000        365.000000
#
#        number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# count        5729.000000            5729.000000             5729.000000
# mean           34.460290               8.775004                0.888288
# std            63.562509              15.895219                1.715670
# min             0.000000               0.000000                0.000000
# 25%             1.000000               0.000000                0.000000
# 50%             9.000000               2.000000                0.000000
# 75%            39.000000              10.000000                1.000000
# max           760.000000             206.000000               23.000000
#
#        review_scores_rating  review_scores_accuracy  \
# count           4606.000000             4585.000000
# mean               4.723139                4.798009
# std                0.544540                0.390754
# min                0.000000                1.000000
# 25%                4.680000                4.770000
# 50%                4.870000                4.920000
# 75%                5.000000                5.000000
# max                5.000000                5.000000
#
#        review_scores_cleanliness  review_scores_checkin  \
# count                4585.000000            4585.000000
# mean                    4.735138               4.866041
# std                     0.450958               0.352986
# min                     1.000000               1.000000
# 25%                     4.670000               4.880000
# 50%                     4.880000               4.970000
# 75%                     5.000000               5.000000
# max                     5.000000               5.000000
#
#        review_scores_communication  review_scores_location  \
# count                  4585.000000             4585.000000
# mean                      4.830600                4.816840
# std                       0.413634                0.347211
# min                       1.000000                1.000000
# 25%                       4.850000                4.790000
# 50%                       4.960000                4.920000
# 75%                       5.000000                5.000000
# max                       5.000000                5.000000
#
#        review_scores_value  calculated_host_listings_count  \
# count          4585.000000                     5729.000000
# mean              4.690475                       43.757898
# std               0.455451                      105.200388
# min               1.000000                        1.000000
# 25%               4.630000                        1.000000
# 50%               4.800000                        3.000000
# 75%               4.940000                       11.000000
# max               5.000000                      362.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                   5729.00000
# mean                                      41.37092
# std                                      105.82580
# min                                        0.00000
# 25%                                        0.00000
# 50%                                        1.00000
# 75%                                        6.00000
# max                                      362.00000
#
#        calculated_host_listings_count_private_rooms  \
# count                                   5729.000000
# mean                                       2.105429
# std                                        6.217265
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        2.000000
# max                                       52.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                  5729.000000        4606.000000
# mean                                      0.281375           1.336198
# std                                       1.888957           1.566881
# min                                       0.000000           0.010000
# 25%                                       0.000000           0.290000
# 50%                                       0.000000           0.810000
# 75%                                       0.000000           1.880000
# max                                      15.000000          19.080000

# %%
abnb_sm_df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'description',
#        'neighborhood_overview', 'picture_url', 'host_id', 'host_url',
#        'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %%
abnb_sm_df = abnb_sm_df[['id', 'host_since', 'host_is_superhost',  'neighbourhood', 'neighbourhood_cleansed', 'latitude','longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'price','minimum_nights', 'maximum_nights', 'calendar_last_scraped', 'number_of_reviews', 'first_review', 'last_review', 'review_scores_rating', 'review_scores_accuracy','review_scores_cleanliness','review_scores_communication', 'review_scores_location','review_scores_value', 'reviews_per_month']]

abnb_sc_df = abnb_sc_df[['id', 'host_since', 'host_is_superhost',  'neighbourhood', 'neighbourhood_cleansed', 'latitude','longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'price','minimum_nights', 'maximum_nights', 'calendar_last_scraped', 'number_of_reviews', 'first_review', 'last_review', 'review_scores_rating', 'review_scores_accuracy','review_scores_cleanliness','review_scores_communication', 'review_scores_location','review_scores_value', 'reviews_per_month']]

# %%
df_main_features(abnb_sm_df)
# Out:
# (3358, 27)
#       id  host_since host_is_superhost                         neighbourhood  \
# 0   4952  2009-01-24                 t  Palo Alto, California, United States
# 1  21373  2009-01-24                 t  Palo Alto, California, United States
# 2  26622  2010-04-24                 f  Daly City, California, United States
# 3  39342  2010-05-18                 f   Pacifica, California, United States
# 4  40560  2010-07-20                 t  Palo Alto, California, United States
#
#   neighbourhood_cleansed  latitude  longitude         property_type  \
# 0   Unincorporated Areas  37.43932 -122.15741          Private room
# 1   Unincorporated Areas  37.43972 -122.15532          Private room
# 2              Daly City  37.69490 -122.47517  Private room in home
# 3               Pacifica  37.62972 -122.48739           Entire home
# 4   Unincorporated Areas  37.45379 -122.13867  Private room in home
#
#          room_type  accommodates  bathrooms  bedrooms  beds    price  \
# 0     Private room             1        NaN       1.0   1.0   $70.00
# 1     Private room             1        NaN       1.0   1.0   $70.00
# 2     Private room             2        NaN       1.0   1.0  $150.00
# 3  Entire home/apt             3        NaN       2.0   2.0  $138.00
# 4     Private room             2        NaN       1.0   1.0  $115.00
#
#    minimum_nights  maximum_nights calendar_last_scraped  number_of_reviews  \
# 0              31             365            2022-06-16                 76
# 1              31             365            2022-06-16                264
# 2               3               7            2022-06-15                255
# 3              31             365            2022-06-15                  3
# 4               2             100            2022-06-16                139
#
#   first_review last_review  review_scores_rating  review_scores_accuracy  \
# 0   2009-08-02  2022-04-02                  4.79                    4.81
# 1   2010-05-28  2022-05-15                  4.87                    4.82
# 2   2010-07-02  2022-05-29                  4.96                    4.96
# 3   2010-08-22  2022-02-05                  4.67                    5.00
# 4   2010-09-18  2022-06-12                  4.91                    4.94
#
#    review_scores_cleanliness  review_scores_communication  \
# 0                       4.88                         4.83
# 1                       4.79                         4.90
# 2                       4.97                         4.95
# 3                       5.00                         5.00
# 4                       4.95                         4.95
#
#    review_scores_location  review_scores_value  reviews_per_month
# 0                    4.89                 4.78               0.48
# 1                    4.96                 4.74               1.80
# 2                    4.73                 4.92               1.75
# 3                    5.00                 5.00               0.02
# 4                    4.94                 4.83               0.97
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3358 entries, 0 to 3357
# Data columns (total 27 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           3358 non-null   int64
#  1   host_since                   3358 non-null   object
#  2   host_is_superhost            3358 non-null   object
#  3   neighbourhood                2340 non-null   object
#  4   neighbourhood_cleansed       3358 non-null   object
#  5   latitude                     3358 non-null   float64
#  6   longitude                    3358 non-null   float64
#  7   property_type                3358 non-null   object
#  8   room_type                    3358 non-null   object
#  9   accommodates                 3358 non-null   int64
#  10  bathrooms                    0 non-null      float64
#  11  bedrooms                     3135 non-null   float64
#  12  beds                         3304 non-null   float64
#  13  price                        3358 non-null   object
#  14  minimum_nights               3358 non-null   int64
#  15  maximum_nights               3358 non-null   int64
#  16  calendar_last_scraped        3358 non-null   object
#  17  number_of_reviews            3358 non-null   int64
#  18  first_review                 2855 non-null   object
#  19  last_review                  2855 non-null   object
#  20  review_scores_rating         2855 non-null   float64
#  21  review_scores_accuracy       2849 non-null   float64
#  22  review_scores_cleanliness    2849 non-null   float64
#  23  review_scores_communication  2849 non-null   float64
#  24  review_scores_location       2849 non-null   float64
#  25  review_scores_value          2849 non-null   float64
#  26  reviews_per_month            2855 non-null   float64
# dtypes: float64(12), int64(5), object(10)
# memory usage: 708.5+ KB
# None
# id                                0
# host_since                        0
# host_is_superhost                 0
# neighbourhood                  1018
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms                      3358
# bedrooms                        223
# beds                             54
# price                             0
# minimum_nights                    0
# maximum_nights                    0
# calendar_last_scraped             0
# number_of_reviews                 0
# first_review                    503
# last_review                     503
# review_scores_rating            503
# review_scores_accuracy          509
# review_scores_cleanliness       509
# review_scores_communication     509
# review_scores_location          509
# review_scores_value             509
# reviews_per_month               503
# dtype: int64
#                  id     latitude    longitude  accommodates  bathrooms  \
# count  3.358000e+03  3358.000000  3358.000000   3358.000000        0.0
# mean   7.216392e+16    37.561683  -122.330873      3.848124        NaN
# std    1.954779e+17     0.103341     0.122456      2.965322        NaN
# min    4.952000e+03    37.137190  -122.519040      0.000000        NaN
# 25%    2.098340e+07    37.468257  -122.445817      2.000000        NaN
# 50%    3.755862e+07    37.549075  -122.336850      3.000000        NaN
# 75%    5.113984e+07    37.658358  -122.219080      5.000000        NaN
# max    6.491004e+17    37.728360  -122.111290     16.000000        NaN
#
#           bedrooms         beds  minimum_nights  maximum_nights  \
# count  3135.000000  3304.000000     3358.000000     3358.000000
# mean      1.790112     2.252724       11.314175      600.114056
# std       1.175409     1.923607       22.333177      528.322304
# min       1.000000     1.000000        1.000000        1.000000
# 25%       1.000000     1.000000        1.000000       45.000000
# 50%       1.000000     2.000000        2.000000      365.000000
# 75%       2.000000     3.000000       20.000000     1125.000000
# max       8.000000    27.000000      365.000000    10000.000000
#
#        number_of_reviews  review_scores_rating  review_scores_accuracy  \
# count        3358.000000           2855.000000             2849.000000
# mean           54.636391              4.766483                4.830702
# std            86.047498              0.426797                0.318881
# min             0.000000              0.000000                1.000000
# 25%             2.000000              4.710000                4.790000
# 50%            19.000000              4.880000                4.920000
# 75%            70.000000              4.980000                5.000000
# max           885.000000              5.000000                5.000000
#
#        review_scores_cleanliness  review_scores_communication  \
# count                2849.000000                  2849.000000
# mean                    4.785869                     4.865721
# std                     0.369339                     0.334824
# min                     1.000000                     1.000000
# 25%                     4.730000                     4.860000
# 50%                     4.900000                     4.960000
# 75%                     5.000000                     5.000000
# max                     5.000000                     5.000000
#
#        review_scores_location  review_scores_value  reviews_per_month
# count             2849.000000          2849.000000        2855.000000
# mean                 4.801232             4.716164           1.857349
# std                  0.308900             0.359869           1.892206
# min                  1.000000             1.000000           0.010000
# 25%                  4.740000             4.640000           0.420000
# 50%                  4.880000             4.800000           1.230000
# 75%                  5.000000             4.910000           2.690000
# max                  5.000000             5.000000          17.740000

# %%
df_main_features(abnb_sc_df)
# Out:
# (5729, 27)
#                    id  host_since host_is_superhost  \
# 0  649100413671762836  2016-07-03                 f
# 1            34284906  2013-06-21                 f
# 2            48658485  2015-01-21                 t
# 3            22251361  2015-11-28                 t
# 4            20761499  2016-06-12                 f
#
#                            neighbourhood neighbourhood_cleansed  latitude  \
# 0                                    NaN              Palo Alto  37.46911
# 1                                    NaN   Unincorporated Areas  37.32758
# 2                                    NaN               Milpitas  37.47384
# 3   Los Gatos, California, United States   Unincorporated Areas  37.12520
# 4  Menlo Park, California, United States   Unincorporated Areas  37.42539
#
#    longitude                property_type        room_type  accommodates  \
# 0 -122.13203          Shared room in home      Shared room             2
# 1 -122.20766            Entire guesthouse  Entire home/apt             2
# 2 -121.91877         Private room in home     Private room             2
# 3 -121.98971           Entire guest suite  Entire home/apt             3
# 4 -122.20023  Private room in rental unit     Private room             1
#
#    bathrooms  bedrooms  beds    price  minimum_nights  maximum_nights  \
# 0        NaN       1.0   2.0   $85.00               1             365
# 1        NaN       1.0   NaN  $299.00               3            1125
# 2        NaN       1.0   1.0   $72.00               1            1125
# 3        NaN       1.0   1.0  $130.00               2              28
# 4        NaN       1.0   1.0   $99.00               1            1125
#
#   calendar_last_scraped  number_of_reviews first_review last_review  \
# 0            2022-06-16                  0          NaN         NaN
# 1            2022-06-15                  0          NaN         NaN
# 2            2022-06-15                 48   2021-03-18  2022-06-06
# 3            2022-06-15                193   2018-02-26  2022-06-13
# 4            2022-06-15                  8   2017-09-14  2022-03-31
#
#    review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                   NaN                     NaN                        NaN
# 1                   NaN                     NaN                        NaN
# 2                  4.83                    4.92                       4.75
# 3                  4.94                    4.93                       4.88
# 4                  4.88                    4.88                       4.38
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                          NaN                     NaN                  NaN
# 1                          NaN                     NaN                  NaN
# 2                         5.00                    4.92                 4.79
# 3                         4.94                    4.89                 4.92
# 4                         5.00                    4.75                 5.00
#
#    reviews_per_month
# 0                NaN
# 1                NaN
# 2               3.16
# 3               3.69
# 4               0.14
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5729 entries, 0 to 5728
# Data columns (total 27 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           5729 non-null   int64
#  1   host_since                   5729 non-null   object
#  2   host_is_superhost            5729 non-null   object
#  3   neighbourhood                3479 non-null   object
#  4   neighbourhood_cleansed       5729 non-null   object
#  5   latitude                     5729 non-null   float64
#  6   longitude                    5729 non-null   float64
#  7   property_type                5729 non-null   object
#  8   room_type                    5729 non-null   object
#  9   accommodates                 5729 non-null   int64
#  10  bathrooms                    0 non-null      float64
#  11  bedrooms                     5347 non-null   float64
#  12  beds                         5620 non-null   float64
#  13  price                        5729 non-null   object
#  14  minimum_nights               5729 non-null   int64
#  15  maximum_nights               5729 non-null   int64
#  16  calendar_last_scraped        5729 non-null   object
#  17  number_of_reviews            5729 non-null   int64
#  18  first_review                 4606 non-null   object
#  19  last_review                  4606 non-null   object
#  20  review_scores_rating         4606 non-null   float64
#  21  review_scores_accuracy       4585 non-null   float64
#  22  review_scores_cleanliness    4585 non-null   float64
#  23  review_scores_communication  4585 non-null   float64
#  24  review_scores_location       4585 non-null   float64
#  25  review_scores_value          4585 non-null   float64
#  26  reviews_per_month            4606 non-null   float64
# dtypes: float64(12), int64(5), object(10)
# memory usage: 1.2+ MB
# None
# id                                0
# host_since                        0
# host_is_superhost                 0
# neighbourhood                  2250
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms                      5729
# bedrooms                        382
# beds                            109
# price                             0
# minimum_nights                    0
# maximum_nights                    0
# calendar_last_scraped             0
# number_of_reviews                 0
# first_review                   1123
# last_review                    1123
# review_scores_rating           1123
# review_scores_accuracy         1144
# review_scores_cleanliness      1144
# review_scores_communication    1144
# review_scores_location         1144
# review_scores_value            1144
# reviews_per_month              1123
# dtype: int64
#                  id     latitude    longitude  accommodates  bathrooms  \
# count  5.729000e+03  5729.000000  5729.000000   5729.000000        0.0
# mean   8.188610e+16    37.351373  -121.974697      3.290103        NaN
# std    2.064451e+17     0.073936     0.118236      2.418787        NaN
# min    4.952000e+03    36.965600  -122.214140      0.000000        NaN
# 25%    2.188225e+07    37.319546  -122.070110      2.000000        NaN
# 50%    3.977334e+07    37.355380  -121.962340      2.000000        NaN
# 75%    5.151011e+07    37.399790  -121.890230      4.000000        NaN
# max    6.494853e+17    37.480080  -121.380120     16.000000        NaN
#
#           bedrooms         beds  minimum_nights  maximum_nights  \
# count  5347.000000  5620.000000     5729.000000     5729.000000
# mean      1.619600     1.931317       13.176121      641.914645
# std       1.037482     1.502533       26.861549      494.059806
# min       1.000000     1.000000        1.000000        1.000000
# 25%       1.000000     1.000000        1.000000       90.000000
# 50%       1.000000     1.000000        3.000000      765.000000
# 75%       2.000000     2.000000       30.000000     1125.000000
# max       9.000000    20.000000      600.000000     1125.000000
#
#        number_of_reviews  review_scores_rating  review_scores_accuracy  \
# count        5729.000000           4606.000000             4585.000000
# mean           34.460290              4.723139                4.798009
# std            63.562509              0.544540                0.390754
# min             0.000000              0.000000                1.000000
# 25%             1.000000              4.680000                4.770000
# 50%             9.000000              4.870000                4.920000
# 75%            39.000000              5.000000                5.000000
# max           760.000000              5.000000                5.000000
#
#        review_scores_cleanliness  review_scores_communication  \
# count                4585.000000                  4585.000000
# mean                    4.735138                     4.830600
# std                     0.450958                     0.413634
# min                     1.000000                     1.000000
# 25%                     4.670000                     4.850000
# 50%                     4.880000                     4.960000
# 75%                     5.000000                     5.000000
# max                     5.000000                     5.000000
#
#        review_scores_location  review_scores_value  reviews_per_month
# count             4585.000000          4585.000000        4606.000000
# mean                 4.816840             4.690475           1.336198
# std                  0.347211             0.455451           1.566881
# min                  1.000000             1.000000           0.010000
# 25%                  4.790000             4.630000           0.290000
# 50%                  4.920000             4.800000           0.810000
# 75%                  5.000000             4.940000           1.880000
# max                  5.000000             5.000000          19.080000

# %%
abnb_df = pd.concat([abnb_sm_df, abnb_sc_df], axis = 0)

# %%
abnb_df = abnb_df.reset_index(drop=True)

# %%
df_main_features(abnb_df)
# Out:
# (9087, 27)
#       id  host_since host_is_superhost                         neighbourhood  \
# 0   4952  2009-01-24                 t  Palo Alto, California, United States
# 1  21373  2009-01-24                 t  Palo Alto, California, United States
# 2  26622  2010-04-24                 f  Daly City, California, United States
# 3  39342  2010-05-18                 f   Pacifica, California, United States
# 4  40560  2010-07-20                 t  Palo Alto, California, United States
#
#   neighbourhood_cleansed  latitude  longitude         property_type  \
# 0   Unincorporated Areas  37.43932 -122.15741          Private room
# 1   Unincorporated Areas  37.43972 -122.15532          Private room
# 2              Daly City  37.69490 -122.47517  Private room in home
# 3               Pacifica  37.62972 -122.48739           Entire home
# 4   Unincorporated Areas  37.45379 -122.13867  Private room in home
#
#          room_type  accommodates  bathrooms  bedrooms  beds    price  \
# 0     Private room             1        NaN       1.0   1.0   $70.00
# 1     Private room             1        NaN       1.0   1.0   $70.00
# 2     Private room             2        NaN       1.0   1.0  $150.00
# 3  Entire home/apt             3        NaN       2.0   2.0  $138.00
# 4     Private room             2        NaN       1.0   1.0  $115.00
#
#    minimum_nights  maximum_nights calendar_last_scraped  number_of_reviews  \
# 0              31             365            2022-06-16                 76
# 1              31             365            2022-06-16                264
# 2               3               7            2022-06-15                255
# 3              31             365            2022-06-15                  3
# 4               2             100            2022-06-16                139
#
#   first_review last_review  review_scores_rating  review_scores_accuracy  \
# 0   2009-08-02  2022-04-02                  4.79                    4.81
# 1   2010-05-28  2022-05-15                  4.87                    4.82
# 2   2010-07-02  2022-05-29                  4.96                    4.96
# 3   2010-08-22  2022-02-05                  4.67                    5.00
# 4   2010-09-18  2022-06-12                  4.91                    4.94
#
#    review_scores_cleanliness  review_scores_communication  \
# 0                       4.88                         4.83
# 1                       4.79                         4.90
# 2                       4.97                         4.95
# 3                       5.00                         5.00
# 4                       4.95                         4.95
#
#    review_scores_location  review_scores_value  reviews_per_month
# 0                    4.89                 4.78               0.48
# 1                    4.96                 4.74               1.80
# 2                    4.73                 4.92               1.75
# 3                    5.00                 5.00               0.02
# 4                    4.94                 4.83               0.97
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9087 entries, 0 to 9086
# Data columns (total 27 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           9087 non-null   int64
#  1   host_since                   9087 non-null   object
#  2   host_is_superhost            9087 non-null   object
#  3   neighbourhood                5819 non-null   object
#  4   neighbourhood_cleansed       9087 non-null   object
#  5   latitude                     9087 non-null   float64
#  6   longitude                    9087 non-null   float64
#  7   property_type                9087 non-null   object
#  8   room_type                    9087 non-null   object
#  9   accommodates                 9087 non-null   int64
#  10  bathrooms                    0 non-null      float64
#  11  bedrooms                     8482 non-null   float64
#  12  beds                         8924 non-null   float64
#  13  price                        9087 non-null   object
#  14  minimum_nights               9087 non-null   int64
#  15  maximum_nights               9087 non-null   int64
#  16  calendar_last_scraped        9087 non-null   object
#  17  number_of_reviews            9087 non-null   int64
#  18  first_review                 7461 non-null   object
#  19  last_review                  7461 non-null   object
#  20  review_scores_rating         7461 non-null   float64
#  21  review_scores_accuracy       7434 non-null   float64
#  22  review_scores_cleanliness    7434 non-null   float64
#  23  review_scores_communication  7434 non-null   float64
#  24  review_scores_location       7434 non-null   float64
#  25  review_scores_value          7434 non-null   float64
#  26  reviews_per_month            7461 non-null   float64
# dtypes: float64(12), int64(5), object(10)
# memory usage: 1.9+ MB
# None
# id                                0
# host_since                        0
# host_is_superhost                 0
# neighbourhood                  3268
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms                      9087
# bedrooms                        605
# beds                            163
# price                             0
# minimum_nights                    0
# maximum_nights                    0
# calendar_last_scraped             0
# number_of_reviews                 0
# first_review                   1626
# last_review                    1626
# review_scores_rating           1626
# review_scores_accuracy         1653
# review_scores_cleanliness      1653
# review_scores_communication    1653
# review_scores_location         1653
# review_scores_value            1653
# reviews_per_month              1626
# dtype: int64
#                  id     latitude    longitude  accommodates  bathrooms  \
# count  9.087000e+03  9087.000000  9087.000000   9087.000000        0.0
# mean   7.829338e+16    37.429090  -122.106318      3.496313        NaN
# std    2.025051e+17     0.133033     0.209554      2.647573        NaN
# min    4.952000e+03    36.965600  -122.519040      0.000000        NaN
# 25%    2.146112e+07    37.338564  -122.254330      2.000000        NaN
# 50%    3.892668e+07    37.404240  -122.092110      2.000000        NaN
# 75%    5.139289e+07    37.482635  -121.936775      4.000000        NaN
# max    6.494853e+17    37.728360  -121.380120     16.000000        NaN
#
#           bedrooms         beds  minimum_nights  maximum_nights  \
# count  8482.000000  8924.000000     9087.000000     9087.000000
# mean      1.682622     2.050314       12.488060      626.467701
# std       1.093528     1.677935       25.297504      507.363417
# min       1.000000     1.000000        1.000000        1.000000
# 25%       1.000000     1.000000        1.000000       90.000000
# 50%       1.000000     1.000000        3.000000      365.000000
# 75%       2.000000     3.000000       28.000000     1125.000000
# max       9.000000    27.000000      600.000000    10000.000000
#
#        number_of_reviews  review_scores_rating  review_scores_accuracy  \
# count        9087.000000           7461.000000             7434.000000
# mean           41.916144              4.739725                4.810538
# std            73.331347              0.503163                0.365210
# min             0.000000              0.000000                1.000000
# 25%             2.000000              4.700000                4.780000
# 50%            12.000000              4.880000                4.920000
# 75%            49.000000              5.000000                5.000000
# max           885.000000              5.000000                5.000000
#
#        review_scores_cleanliness  review_scores_communication  \
# count                7434.000000                  7434.000000
# mean                    4.754580                     4.844060
# std                     0.422245                     0.385695
# min                     1.000000                     1.000000
# 25%                     4.700000                     4.860000
# 50%                     4.890000                     4.960000
# 75%                     5.000000                     5.000000
# max                     5.000000                     5.000000
#
#        review_scores_location  review_scores_value  reviews_per_month
# count             7434.000000           7434.00000        7461.000000
# mean                 4.810858              4.70032           1.535620
# std                  0.333115              0.42155           1.717404
# min                  1.000000              1.00000           0.010000
# 25%                  4.760000              4.64000           0.330000
# 50%                  4.900000              4.80000           0.950000
# 75%                  5.000000              4.93000           2.150000
# max                  5.000000              5.00000          19.080000

# %%
abnb_df
# Out:
#             id  host_since host_is_superhost  \
# 0         4952  2009-01-24                 t
# 1        21373  2009-01-24                 t
# 2        26622  2010-04-24                 f
# 3        39342  2010-05-18                 f
# 4        40560  2010-07-20                 t
# ...        ...         ...               ...
# 9082  48503190  2012-09-03                 t
# 9083  35671852  2019-06-13                 t
# 9084  32008649  2015-10-08                 t
# 9085  31801684  2015-10-08                 t
# 9086   9062857  2014-09-30                 t
#
#                                   neighbourhood neighbourhood_cleansed  \
# 0          Palo Alto, California, United States   Unincorporated Areas
# 1          Palo Alto, California, United States   Unincorporated Areas
# 2          Daly City, California, United States              Daly City
# 3           Pacifica, California, United States               Pacifica
# 4          Palo Alto, California, United States   Unincorporated Areas
# ...                                         ...                    ...
# 9082                                        NaN              Palo Alto
# 9083  East Palo Alto, California, United States              Palo Alto
# 9084  East Palo Alto, California, United States              Palo Alto
# 9085       Palo Alto, California, United States              Palo Alto
# 9086      Menlo Park, California, United States              Palo Alto
#
#       latitude  longitude         property_type        room_type  \
# 0     37.43932 -122.15741          Private room     Private room
# 1     37.43972 -122.15532          Private room     Private room
# 2     37.69490 -122.47517  Private room in home     Private room
# 3     37.62972 -122.48739           Entire home  Entire home/apt
# 4     37.45379 -122.13867  Private room in home     Private room
# ...        ...        ...                   ...              ...
# 9082  37.45978 -122.14339    Entire guest suite  Entire home/apt
# 9083  37.45987 -122.12973           Entire home  Entire home/apt
# 9084  37.45981 -122.14745           Entire home  Entire home/apt
# 9085  37.46018 -122.14418           Entire home  Entire home/apt
# 9086  37.45578 -122.15756           Entire home  Entire home/apt
#
#       accommodates  bathrooms  bedrooms  beds    price  minimum_nights  \
# 0                1        NaN       1.0   1.0   $70.00              31
# 1                1        NaN       1.0   1.0   $70.00              31
# 2                2        NaN       1.0   1.0  $150.00               3
# 3                3        NaN       2.0   2.0  $138.00              31
# 4                2        NaN       1.0   1.0  $115.00               2
# ...            ...        ...       ...   ...      ...             ...
# 9082             3        NaN       NaN   4.0  $100.00               2
# 9083             3        NaN       NaN   2.0  $129.00               3
# 9084             4        NaN       2.0   2.0  $169.00               3
# 9085             4        NaN       2.0   2.0  $169.00               3
# 9086             6        NaN       3.0   3.0  $636.00               4
#
#       maximum_nights calendar_last_scraped  number_of_reviews first_review  \
# 0                365            2022-06-16                 76   2009-08-02
# 1                365            2022-06-16                264   2010-05-28
# 2                  7            2022-06-15                255   2010-07-02
# 3                365            2022-06-15                  3   2010-08-22
# 4                100            2022-06-16                139   2010-09-18
# ...              ...                   ...                ...          ...
# 9082              28            2022-06-15                 40   2021-06-23
# 9083            1125            2022-06-15                 58   2019-06-22
# 9084            1125            2022-06-15                103   2019-02-13
# 9085            1125            2022-06-15                 88   2019-03-05
# 9086            1125            2022-06-15                105   2015-11-05
#
#      last_review  review_scores_rating  review_scores_accuracy  \
# 0     2022-04-02                  4.79                    4.81
# 1     2022-05-15                  4.87                    4.82
# 2     2022-05-29                  4.96                    4.96
# 3     2022-02-05                  4.67                    5.00
# 4     2022-06-12                  4.91                    4.94
# ...          ...                   ...                     ...
# 9082  2022-06-12                  4.88                    4.88
# 9083  2022-05-09                  4.97                    4.98
# 9084  2022-06-08                  4.94                    4.99
# 9085  2022-06-09                  4.84                    4.92
# 9086  2021-08-29                  4.96                    4.98
#
#       review_scores_cleanliness  review_scores_communication  \
# 0                          4.88                         4.83
# 1                          4.79                         4.90
# 2                          4.97                         4.95
# 3                          5.00                         5.00
# 4                          4.95                         4.95
# ...                         ...                          ...
# 9082                       4.90                         5.00
# 9083                       4.93                         4.93
# 9084                       4.94                         5.00
# 9085                       4.92                         4.98
# 9086                       4.98                         4.95
#
#       review_scores_location  review_scores_value  reviews_per_month
# 0                       4.89                 4.78               0.48
# 1                       4.96                 4.74               1.80
# 2                       4.73                 4.92               1.75
# 3                       5.00                 5.00               0.02
# 4                       4.94                 4.83               0.97
# ...                      ...                  ...                ...
# 9082                    4.65                 4.88               3.35
# 9083                    4.76                 4.83               1.60
# 9084                    4.92                 4.93               2.53
# 9085                    4.85                 4.86               2.20
# 9086                    4.96                 4.77               1.30
#
# [9087 rows x 27 columns]

# %% [markdown]
# # Cleaning

# %%
def airbnb_cleaning(x):
    abnb_df = x
    

    # drop columns
    abnb_df = abnb_df.drop(columns=['bathrooms','property_type'], axis=1)
    
    
    # replace * in the column
    abnb_df['neighbourhood'] =abnb_df['neighbourhood'].str.replace(',.*', '')
    
    # fill na in the column
    abnb_df['neighbourhood'] = abnb_df['neighbourhood'].fillna(abnb_df['neighbourhood_cleansed'])
    
    
    # function ro replace characters in the column
    neigh_names = list(abnb_df['neighbourhood'].unique())
    neigh_names
    # neigh_names.remove(np.nan)
    neigh_names.remove('圣何塞')
    neigh_names.remove(' ')
    
    def neigh_sel(row):
        if row['neighbourhood'] in neigh_names:
            return row['neighbourhood']
        else:
            return row['neighbourhood_cleansed']
        return row['neighbourhood'] 
    
    abnb_df['neighbourhood'] = abnb_df.apply(neigh_sel, axis=1)
    
    # dropping the unneccessary column
    abnb_df = abnb_df.drop('neighbourhood_cleansed', axis=1)
    
    
    # fill the nans with mean of the columns
    cols_to_fill = ['bedrooms', 'beds', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'reviews_per_month']
    for i in cols_to_fill:
        abnb_df[i].fillna(abnb_df[i].mean(), inplace=True)
    
    # number of reviews are zero in some rows so the other related columns should be 0
    num_rev_zeros = abnb_df[abnb_df['number_of_reviews']==0].index
    cols_to_edit = ['first_review','last_review', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'reviews_per_month']
    abnb_df.loc[num_rev_zeros, cols_to_edit] = 0
    
    # changing the dollar sign
    abnb_df.price = abnb_df.price.str.replace('$','')
    abnb_df.price = pd.to_numeric(abnb_df.price, errors='coerce')
    
    
    # datetime conversion
    abnb_df['host_since']=pd.to_datetime(abnb_df['host_since'])
    abnb_df['calendar_last_scraped']=pd.to_datetime(abnb_df['calendar_last_scraped'])
    abnb_df['first_review']=pd.to_datetime(abnb_df['first_review'])
    abnb_df['last_review']=pd.to_datetime(abnb_df['last_review'])
    
        
    # transforming accommodates column
    accommodates_labels = ['Single', 'Couple', 'Small groups', 'Medium groups', 'Large Groups']
    abnb_df['accommodates_def'] = pd.cut(abnb_df['accommodates'],[0,1,2,6,12,17],labels=accommodates_labels)
    abnb_df[['accommodates','accommodates_def']].head(20)
    abnb_df['accommodates'] = abnb_df['accommodates_def']
        
        
    # airbnb hotel room     
    abnb_df = abnb_df[~abnb_df.room_type.str.contains("Hotel room")]   
    
    
    
    # counties
    count_counties = abnb_df.neighbourhood.value_counts(dropna=False)
    less_counties = list(count_counties[count_counties < 50].index)
    abnb_df['neighbourhood'] = np.where(abnb_df['neighbourhood'].isin(less_counties),'other', abnb_df['neighbourhood'])
    
    
    # dropped more cols
    abnb_df = abnb_df.drop(columns = ['calendar_last_scraped', 'first_review', 'last_review'],axis=1)
        
        
        
    # extracting the year    
    abnb_df['host_since'] = pd.DatetimeIndex(abnb_df['host_since']).year
    
    
    # host_since labelling
    host_since_labels = ['2009-2012', '2013-2016', '2017-2020', '2021-2022']
    abnb_df['host_since_def'] = pd.cut(abnb_df['host_since'],[2008,2012,2016,2020,2022],labels=host_since_labels)
    abnb_df['host_since'] = abnb_df['host_since_def']
    
    
    
    # dropping cols that was created
    abnb_df=abnb_df.drop(columns = ['accommodates_def','host_since_def'], axis=1)

    return abnb_df

# %%
listing_cleaned = airbnb_cleaning(abnb_df)

# %%
listing_cleaned
# Out:
#             id host_since host_is_superhost   neighbourhood  latitude  \
# 0         4952  2009-2012                 t       Palo Alto  37.43932
# 1        21373  2009-2012                 t       Palo Alto  37.43972
# 2        26622  2009-2012                 f       Daly City  37.69490
# 3        39342  2009-2012                 f        Pacifica  37.62972
# 4        40560  2009-2012                 t       Palo Alto  37.45379
# ...        ...        ...               ...             ...       ...
# 9082  48503190  2009-2012                 t       Palo Alto  37.45978
# 9083  35671852  2017-2020                 t  East Palo Alto  37.45987
# 9084  32008649  2013-2016                 t  East Palo Alto  37.45981
# 9085  31801684  2013-2016                 t       Palo Alto  37.46018
# 9086   9062857  2013-2016                 t      Menlo Park  37.45578
#
#       longitude        room_type  accommodates  bedrooms  beds  price  \
# 0    -122.15741     Private room        Single  1.000000   1.0   70.0
# 1    -122.15532     Private room        Single  1.000000   1.0   70.0
# 2    -122.47517     Private room        Couple  1.000000   1.0  150.0
# 3    -122.48739  Entire home/apt  Small groups  2.000000   2.0  138.0
# 4    -122.13867     Private room        Couple  1.000000   1.0  115.0
# ...         ...              ...           ...       ...   ...    ...
# 9082 -122.14339  Entire home/apt  Small groups  1.682622   4.0  100.0
# 9083 -122.12973  Entire home/apt  Small groups  1.682622   2.0  129.0
# 9084 -122.14745  Entire home/apt  Small groups  2.000000   2.0  169.0
# 9085 -122.14418  Entire home/apt  Small groups  2.000000   2.0  169.0
# 9086 -122.15756  Entire home/apt  Small groups  3.000000   3.0  636.0
#
#       minimum_nights  maximum_nights  number_of_reviews  review_scores_rating  \
# 0                 31             365                 76                  4.79
# 1                 31             365                264                  4.87
# 2                  3               7                255                  4.96
# 3                 31             365                  3                  4.67
# 4                  2             100                139                  4.91
# ...              ...             ...                ...                   ...
# 9082               2              28                 40                  4.88
# 9083               3            1125                 58                  4.97
# 9084               3            1125                103                  4.94
# 9085               3            1125                 88                  4.84
# 9086               4            1125                105                  4.96
#
#       review_scores_accuracy  review_scores_cleanliness  \
# 0                       4.81                       4.88
# 1                       4.82                       4.79
# 2                       4.96                       4.97
# 3                       5.00                       5.00
# 4                       4.94                       4.95
# ...                      ...                        ...
# 9082                    4.88                       4.90
# 9083                    4.98                       4.93
# 9084                    4.99                       4.94
# 9085                    4.92                       4.92
# 9086                    4.98                       4.98
#
#       review_scores_communication  review_scores_location  \
# 0                            4.83                    4.89
# 1                            4.90                    4.96
# 2                            4.95                    4.73
# 3                            5.00                    5.00
# 4                            4.95                    4.94
# ...                           ...                     ...
# 9082                         5.00                    4.65
# 9083                         4.93                    4.76
# 9084                         5.00                    4.92
# 9085                         4.98                    4.85
# 9086                         4.95                    4.96
#
#       review_scores_value  reviews_per_month
# 0                    4.78               0.48
# 1                    4.74               1.80
# 2                    4.92               1.75
# 3                    5.00               0.02
# 4                    4.83               0.97
# ...                   ...                ...
# 9082                 4.88               3.35
# 9083                 4.83               1.60
# 9084                 4.93               2.53
# 9085                 4.86               2.20
# 9086                 4.77               1.30
#
# [9085 rows x 21 columns]

# %%
listing_cleaned.to_csv("/Users/begumerdem/IH-Labs/WEEK_5_Lab/archive/abnb_listings_cleaned.csv", index = False)

# %%
import pymysql
from sqlalchemy import create_engine

from getpass import getpass  # To get the password without showing the input

# %%
password = getpass()
# Out:
# ········

# %%
connection_string = 'mysql+pymysql://root:'+password+'@localhost/airbnb'
engine = create_engine(connection_string)

# %%
listing_cleaned.to_sql('listings', engine, if_exists='replace', index = False)
# Out:
# 9085

# %%
categorical_df = abnb_df.select_dtypes(object)
categorical_df

# %%
numerical_df = abnb_df.select_dtypes(exclude='object')
numerical_df

# %%
# Defining a function that differentiates between continuous and discrete variables

def differ_cont_disc(df):
    
    df_continuous = pd.DataFrame()
    df_discrete = pd.DataFrame()
    
    for name in df.columns:
        if df[name].nunique() >50:
            df_continuous[name] = df[name]
        else:
            df_discrete[name] = df[name]
    return df_continuous, df_discrete


continuous_df, discrete_df = differ_cont_disc(numerical_df)

# %%
continuous_df

# %%
discrete_df

# %%
# Plotting a correlation matrix

# %%
correlations = continuous_df.corr()
correlations

# %%
correlations = abnb_df.corr()
correlations

# %%
# Plotting a correlation matrix to see what's happening with numerical values

fig, ax=plt.subplots(figsize=(10,8))
correlations_matrix = continuous_df.corr()
sns.heatmap(correlations_matrix, annot=True)
plt.show()

# %%
# after seeing the heat map I've decided to keep only review_scores_rating 
# and reviews per month columns from all other columns for the review feature.
# since there is a very high correlatio among review columns

# %%
abnb_df = abnb_df.drop(['review_scores_accuracy','review_scores_cleanliness','review_scores_communication', 'review_scores_location', 'review_scores_value'], axis=1)

# %%
abnb_df

# %%
# plotting variable types

# %%
def plot_cont_displot(df):
    for name in df.columns:
        sns.displot(data=df, x=name, kde=True)
    return

plot_cont_displot(discrete_df)

# %%
def plot_cont_displot(df):
    for name in df.columns:
        sns.displot(data=df, x=name, kde=True)
    return

plot_cont_displot(continuous_df)

# %%
# outliers in continuous variables

# %%
def outliers_cont(df):
    for name in df.columns:
        sns.boxplot(data=df, x=name)
        plt.show()
    
outliers_cont(continuous_df)

# %%
def detect_outlier(column):
    # find q1 and q3 values
    q1, q3 = np.percentile(sorted(column), [25, 75])
 
    # compute IQR
    iqr = q3 - q1
 
    # find lower and upper bounds
    lower_bound = q1 - (1.5 * iqr)
    upper_bound = q3 + (1.5 * iqr)
 
    outliers = [x for x in column if x <= lower_bound or x >= upper_bound]
 
    return outliers

# %%
# input data
rsr_outliers = detect_outlier(continuous_df['review_scores_rating'])
rpm_outliers = detect_outlier(continuous_df['reviews_per_month'])
mn_outliers = detect_outlier(continuous_df['minimum_nights'])

# %%
display(len(rsr_outliers))
display(len(rpm_outliers))
display(len(mn_outliers))

# %%
abnb_df.describe()

# %%
# about the high number of outliers, I don't think that is not reasonable.
# some properties got so many reviews while some of them didn't get any
# likewise some properties

# %%
# abnb_df.loc[:, 'accommodates':'beds'].apply(np.argmax, axis =0)

# %%
# abnb_df.loc[633:639, 'accommodates':'beds']

# %%
# abnb_df.loc[420:426, 'accommodates':'beds']

# %%
# abnb_df.loc[7565:7575, 'accommodates':'beds']

# %%
# I also checked the airbnb pages or that houses to see 
# whether the numbers are accurate and they are accurate 
# so I'm not dropping the outliers

# %%
abnb_df

# %%
abnb_df.nunique()

# %%
numerical_df.nunique()

# %%
continuous_df.nunique()

# %%
discrete_df.nunique()

# %%
categorical_df.nunique()

# %%
categorical_df = pd.concat([discrete_df, categorical_df], axis = 1)
categorical_df = categorical_df.reset_index(drop=True)

# %%
categorical_df

# %%
numerical_df = continuous_df

# %%
numerical_df

# %%
# Finally: Looking at numerical and categorical variables one last time

# %%
# Looking at Categorical features

def cntplot_cat(df):
    for column in df.columns:
        sns.countplot(x=df[column])
        plt.show()
    return None
   

cntplot_cat(categorical_df)

# %%
# just realized the datatype of price is wrong so need to change and rerun datatypes

# %%
abnb_df.price

# %%
def cntplot_cat(df):
    for column in df.columns:
        sns.countplot(x=df[column])
        plt.show()
    return None
   

cntplot_cat(categorical_df)

# %%
abnb_df.info()

# %%
abnb_df

# %%
abnb_df.neighbourhood.nunique()

# %%
abnb_df.to_csv("/Users/begumerdem/IH-Labs/WEEK_5_Lab/archive/cleaned_airbnb_01.csv")

# If you just use file name then it will save CSV file in working directory.
# Example path : C:/Users/<>/Desktop/<file name>.csv
